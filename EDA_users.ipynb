# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('yelp_academic_dataset_user.csv')

# %%
df.head()
# Out:
#   yelping_since  useful  compliment_photos  compliment_list  compliment_funny  \
# 0    2015-09-28       0                  0                0                 0
# 1    2015-09-05       0                  0                0                 0
# 2    2016-07-21       0                  0                0                 0
# 3    2014-08-04       0                  0                0                 0
# 4    2017-06-18       0                  0                0                 0
#
#    compliment_plain  review_count elite  fans  compliment_note  \
# 0                 0             1  None     0                0
# 1                 0             2  None     0                0
# 2                 0             1  None     0                0
# 3                 0            19  None     0                0
# 4                 0             3  None     0                0
#
#         ...        compliment_cute  average_stars                 user_id  \
# ...

# %%
print("Number of users :", df.shape[0])
print("Number of attributes per user :", df.shape[1])
# Out:
# Number of users : 1518169
# Number of attributes per user : 22

# %%
df["yelping_since"] = df["yelping_since"].astype("datetime64")
pltd = df.groupby(df["yelping_since"].dt.year)['user_id'].count().plot(kind="bar", title='User growth over the years')
pltd.set_xlabel('Year')
pltd.set_ylabel('Number')
# Out:
# Text(0, 0.5, 'Number')

# %%
df.describe()
# Out:
#              useful  compliment_photos  compliment_list  compliment_funny  \
# count  1.518169e+06       1.518169e+06     1.518169e+06      1.518169e+06
# mean   2.866694e+01       1.161873e+00     8.959674e-02      3.257744e+00
# std    7.301740e+02       9.679741e+01     1.129681e+01      8.910309e+01
# min    0.000000e+00       0.000000e+00     0.000000e+00      0.000000e+00
# 25%    0.000000e+00       0.000000e+00     0.000000e+00      0.000000e+00
# 50%    0.000000e+00       0.000000e+00     0.000000e+00      0.000000e+00
# 75%    3.000000e+00       0.000000e+00     0.000000e+00      0.000000e+00
# max    2.584790e+05       8.259300e+04     1.266300e+04      3.069900e+04
#
#        compliment_plain  review_count          fans  compliment_note  \
# count      1.518169e+06  1.518169e+06  1.518169e+06     1.518169e+06
# mean       3.239886e+00  2.243219e+01  1.453618e+00     1.550980e+00
# std        9.271578e+01  7.750849e+01  1.519258e+01     5.734051e+01
# ...
